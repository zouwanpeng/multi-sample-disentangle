# %% [markdown]
# # This is a tutorial of using spaMultiVAE for the spatial multi-omics DBiT-seq data

# %% [markdown]
# This tutorial was implemented on Macbook Pro M2.
#
# Import modules.

# %%
import math, os
from time import time

import torch
from spaMultiVAE import SPAMULTIVAE
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.mixture import GaussianMixture
from sklearn.neighbors import NearestNeighbors
import h5py
import scanpy as sc
from preprocess import normalize, geneSelection

# %% [markdown]
# Setup parameters.

# %%
'''
Parameter setting
'''

class Args(object):
    def __init__(self):
        self.data_file = 'humantonsil_SVG.h5'
        self.select_genes = 0
        self.select_proteins = 0
        self.batch_size = "auto"
        self.maxiter = 5000
        self.train_size = 0.95
        self.patience = 200
        self.lr = 5e-3
        self.weight_decay = 1e-6
        self.gene_noise = 0
        self.protein_noise = 0
        self.dropoutE = 0
        self.dropoutD = 0
        self.encoder_layers = [128, 64]
        self.GP_dim = 2
        self.Normal_dim = 18
        self.gene_decoder_layers = [128]
        self.protein_decoder_layers = [128]
        self.init_beta = 10
        self.min_beta = 4
        self.max_beta = 25
        self.KL_loss = 0.025
        self.num_samples = 1
        self.fix_inducing_points = True
        self.inducing_point_steps = 19
        self.fixed_gp_params = False
        self.loc_range = 20.
        self.kernel_scale = 20.
        self.model_file = "model.pt"
        self.final_latent_file = "final_latent.txt"
        self.gene_denoised_counts_file = "gene_denoised_counts.txt"
        self.protein_denoised_counts_file = "protein_denoised_counts.txt"
        self.protein_sigmoid_file = "protein_sigmoid.txt"
        self.gene_enhanced_denoised_counts_file = "gene_enhanced_denoised_counts.txt"
        self.protein_enhanced_denoised_counts_file = "protein_enhanced_denoised_counts.txt"
        self.enhanced_loc_file = "enhanced_loc.txt"
        self.device = "cpu"

args = Args()

# %% [markdown]
# Setup inducing points, preprocess count matrices, initial protein background priors, and build the spaMultiVAE model.

# %%
data_mat = h5py.File(args.data_file, 'r')
x1 = np.array(data_mat['X_gene']).astype('float64')     # gene count matrix
x2 = np.array(data_mat['X_protein']).astype('float64')  # protein count matrix
loc = np.array(data_mat['pos']).astype('float64')       # location information
data_mat.close()

if args.batch_size == "auto":
    if x1.shape[0] <= 1024:
        args.batch_size = 128
    elif x1.shape[0] <= 2048:
        args.batch_size = 256
    else:
        args.batch_size = 512
else:
    args.batch_size = int(args.batch_size)
    
print(args)

if args.select_genes > 0:
    importantGenes = geneSelection(x1, n=args.select_genes, plot=False)
    x1 = x1[:, importantGenes]
    np.savetxt("selected_genes.txt", importantGenes, delimiter=",", fmt="%i")

if args.select_proteins > 0:
    importantProteins = geneSelection(x2, n=args.select_proteins, plot=False)
    x2 = x2[:, importantProteins]
    np.savetxt("selected_proteins.txt", importantProteins, delimiter=",", fmt="%i")

scaler = MinMaxScaler()
loc = scaler.fit_transform(loc) * args.loc_range

print(x1.shape)
print(x2.shape)
print(loc.shape)

eps = 1e-5
initial_inducing_points = np.mgrid[0:(1+eps):(1./args.inducing_point_steps), 0:(1+eps):(1./args.inducing_point_steps)].reshape(2, -1).T * args.loc_range
print(initial_inducing_points.shape)

adata1 = sc.AnnData(x1, dtype="float64")
adata1 = normalize(adata1,
                  size_factors=True,
                  normalize_input=True,
                  logtrans_input=True)

adata2 = sc.AnnData(x2, dtype="float64")
adata2 = normalize(adata2,
                  size_factors=False,
                  normalize_input=True,
                  logtrans_input=True)

adata2_no_scale = sc.AnnData(x2, dtype="float64")
adata2_no_scale = normalize(adata2_no_scale,
                  size_factors=False,
                  normalize_input=False,
                  logtrans_input=True)

# Fit GMM model to the protein counts and use the smaller component as the initial values as protein background prior
gm = GaussianMixture(n_components=2, covariance_type="diag", n_init=20).fit(adata2_no_scale.X)
back_idx = np.argmin(gm.means_, axis=0)
protein_log_back_mean = np.log(np.expm1(gm.means_[back_idx, np.arange(adata2_no_scale.n_vars)]))
protein_log_back_scale = np.sqrt(gm.covariances_[back_idx, np.arange(adata2_no_scale.n_vars)])
print("protein_back_mean shape", protein_log_back_mean.shape)

model = SPAMULTIVAE(gene_dim=adata1.n_vars, protein_dim=adata2.n_vars, GP_dim=args.GP_dim, Normal_dim=args.Normal_dim, 
    encoder_layers=args.encoder_layers, gene_decoder_layers=args.gene_decoder_layers, protein_decoder_layers=args.protein_decoder_layers,
    gene_noise=args.gene_noise, protein_noise=args.protein_noise, encoder_dropout=args.dropoutE, decoder_dropout=args.dropoutD,
    fixed_inducing_points=args.fix_inducing_points, initial_inducing_points=initial_inducing_points, 
    fixed_gp_params=args.fixed_gp_params, kernel_scale=args.kernel_scale, N_train=adata1.n_obs, KL_loss=args.KL_loss, init_beta=args.init_beta, min_beta=args.min_beta, 
    max_beta=args.max_beta, protein_back_mean=protein_log_back_mean, protein_back_scale=protein_log_back_scale, dtype=torch.float64, 
    device=args.device)

print(str(model))
# Out:
# <__main__.Args object at 0x2c1101210>
# (2492, 984)
# (2492, 283)
# (2492, 2)
# (400, 2)
# protein_back_mean shape (283,)
# SPAMULTIVAE(
#   (svgp): SVGP(
#     (kernel): CauchyKernel()
#   )
#   (encoder): DenseEncoder(
#     (layers): Sequential(
#       (0): Linear(in_features=1267, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ELU(alpha=1.0)
#       (3): Linear(in_features=128, out_features=64, bias=True)
#       (4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ELU(alpha=1.0)
#     )
#     (enc_mu): Linear(in_features=64, out_features=20, bias=True)
#     (enc_var): Linear(in_features=64, out_features=20, bias=True)
#   )
#   (gene_decoder): Sequential(
#     (0): Linear(in_features=20, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#   )
#   (gene_dec_mean): Sequential(
#     (0): Linear(in_features=128, out_features=984, bias=True)
#     (1): MeanAct()
#   )
#   (protein_decoder): Sequential(
#     (0): Linear(in_features=20, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#   )
#   (protein_back_decoder): Sequential(
#     (0): Linear(in_features=20, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#   )
#   (protein_back_prop_logit_decoder): Sequential(
#     (0): Linear(in_features=20, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ELU(alpha=1.0)
#   )
#   (protein_fore_mean): Sequential(
#     (0): Linear(in_features=128, out_features=283, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#   )
#   (protein_back_log_mean_dec): Linear(in_features=128, out_features=283, bias=True)
#   (protein_back_log_scale_dec): Linear(in_features=128, out_features=283, bias=True)
#   (protein_back_prop_logit): Linear(in_features=128, out_features=283, bias=True)
#   (NB_loss): NBLoss()
#   (MixtureNB_loss): MixtureNBLoss()
# )

# %% [markdown]
# Train the model.

# %%
if not os.path.isfile(args.model_file):
    t0 = time()
    model.train_model(pos=loc, gene_ncounts=adata1.X, gene_raw_counts=adata1.raw.X, gene_size_factors=adata1.obs.size_factors, 
                protein_ncounts=adata2.X, protein_raw_counts=adata2.raw.X,
                lr=args.lr, weight_decay=args.weight_decay, batch_size=args.batch_size, num_samples=args.num_samples,
                train_size=args.train_size, maxiter=args.maxiter, patience=args.patience, save_model=True, model_weights=args.model_file)
    print('Training time: %d seconds.' % int(time() - t0))
else:
    model.load_model(args.model_file)

final_latent = model.batching_latent_samples(X=loc, gene_Y=adata1.X, protein_Y=adata2.X, batch_size=args.batch_size)
np.savetxt(args.final_latent_file, final_latent, delimiter=",")


gene_denoised_counts, protein_denoised_counts, protein_sigmoid = model.batching_denoise_counts(X=loc, gene_Y=adata1.X, protein_Y=adata2.X, batch_size=args.batch_size, n_samples=25)
np.savetxt(args.gene_denoised_counts_file, gene_denoised_counts, delimiter=",")
np.savetxt(args.protein_denoised_counts_file, protein_denoised_counts, delimiter=",")
np.savetxt(args.protein_sigmoid_file, protein_sigmoid, delimiter=",")
# Out:
# Training
# Training epoch 1, ELBO:8845.24704627, Gene NB loss:1794.74566083, Protein NB mixture loss:2953.75140669, Protein background KL:4054.38022947, GP KLD loss:0.05753699, Gaussian KLD loss:4.12662983, noise regularization:0.000000
# Current beta 10.329338480578347
# Current kernel scale tensor([20.0005])
# Training epoch 1, validating ELBO:6888.15421667
# Training epoch 2, ELBO:6092.24007332, Gene NB loss:1550.18661292, Protein NB mixture loss:1934.21461802, Protein background KL:2550.06790394, GP KLD loss:0.05065089, Gaussian KLD loss:5.46199621, noise regularization:0.000000
# Current beta 10.747842906749597
# Current kernel scale tensor([20.0167])
# Training epoch 2, validating ELBO:4846.83589513
# Training epoch 3, ELBO:4321.12740254, Gene NB loss:1376.08018472, Protein NB mixture loss:1369.11522723, Protein background KL:1531.66894234, GP KLD loss:0.05256849, Gaussian KLD loss:4.00918078, noise regularization:0.000000
# Current beta 11.177512703222344
# Current kernel scale tensor([20.0336])
# Training epoch 3, validating ELBO:3569.29593808
# Training epoch 4, ELBO:3261.59192824, Gene NB loss:1277.68939904, Protein NB mixture loss:1062.72938572, Protein background KL:878.59178362, GP KLD loss:0.05057838, Gaussian KLD loss:3.70776807, noise regularization:0.000000
# Current beta 11.575455705525725
# Current kernel scale tensor([20.0492])
# Training epoch 4, validating ELBO:2816.89457958
# Training epoch 5, ELBO:2723.99373888, Gene NB loss:1226.07938279, Protein NB mixture loss:929.17723487, Protein background KL:529.14848981, GP KLD loss:0.04906740, Gaussian KLD loss:3.33363735, noise regularization:0.000000
# Current beta 11.901375287716139
# Current kernel scale tensor([20.0613])
# Training epoch 5, validating ELBO:2537.76747839
# Training epoch 6, ELBO:2482.97459984, Gene NB loss:1196.57665043, Protein NB mixture loss:874.96219636, Protein background KL:374.64761861, GP KLD loss:0.05944324, Gaussian KLD loss:3.00440229, noise regularization:0.000000
# Current beta 12.197133164859906
# Current kernel scale tensor([20.0704])
# Training epoch 6, validating ELBO:2400.96128363
# Training epoch 7, ELBO:2378.82393766, Gene NB loss:1179.36590865, Protein NB mixture loss:858.02067480, Protein background KL:309.30894880, GP KLD loss:0.09306782, Gaussian KLD loss:2.51932162, noise regularization:0.000000
# Current beta 12.452991752450956
# Current kernel scale tensor([20.0779])
# Training epoch 7, validating ELBO:2335.24598078
# Training epoch 8, ELBO:2309.44590883, Gene NB loss:1171.46881937, Protein NB mixture loss:851.15867407, Protein background KL:254.65640484, GP KLD loss:0.10436967, Gaussian KLD loss:2.46110174, noise regularization:0.000000
# Current beta 12.67993948838317
# Current kernel scale tensor([20.0879])
# Training epoch 8, validating ELBO:2251.64842381
# Training epoch 9, ELBO:2236.26844599, Gene NB loss:1161.23986987, Protein NB mixture loss:843.32512309, Protein background KL:206.38254397, GP KLD loss:0.12352303, Gaussian KLD loss:1.86207094, noise regularization:0.000000
# Current beta 12.875814901341176
# Current kernel scale tensor([20.0866])
# Training epoch 9, validating ELBO:2218.04158620
# Training epoch 10, ELBO:2196.95926820, Gene NB loss:1160.61752827, Protein NB mixture loss:842.76168143, Protein background KL:170.41820594, GP KLD loss:0.16135546, Gaussian KLD loss:1.62866647, noise regularization:0.000000
# Current beta 13.039183014009035
# Current kernel scale tensor([20.0787])
# Training epoch 10, validating ELBO:2172.62030253
# Training epoch 11, ELBO:2166.24200901, Gene NB loss:1158.13966261, Protein NB mixture loss:840.01461669, Protein background KL:145.95870015, GP KLD loss:0.13511466, Gaussian KLD loss:1.55531445, noise regularization:0.000000
# Current beta 13.172348023205807
# Current kernel scale tensor([20.0665])
# Training epoch 11, validating ELBO:2146.14082403
# Training epoch 12, ELBO:2141.52358024, Gene NB loss:1151.42667504, Protein NB mixture loss:836.70040968, Protein background KL:131.05619696, GP KLD loss:0.13871103, Gaussian KLD loss:1.55142530, noise regularization:0.000000
# Current beta 13.295430661693763
# Current kernel scale tensor([20.0504])
# Training epoch 12, validating ELBO:2132.89769340
# Training epoch 13, ELBO:2114.72260886, Gene NB loss:1149.50692849, Protein NB mixture loss:831.53900474, Protein background KL:114.47521912, GP KLD loss:0.13160839, Gaussian KLD loss:1.30806698, noise regularization:0.000000
# Current beta 13.409140796250652
# Current kernel scale tensor([20.0327])
# Training epoch 13, validating ELBO:2129.58381128
# Training epoch 14, ELBO:2102.89386017, Gene NB loss:1147.08169782, Protein NB mixture loss:830.56297846, Protein background KL:109.04027353, GP KLD loss:0.14014346, Gaussian KLD loss:1.06528964, noise regularization:0.000000
# Current beta 13.506004583951748
# Current kernel scale tensor([20.0190])
# Training epoch 14, validating ELBO:2103.52301787
# Training epoch 15, ELBO:2094.21773355, Gene NB loss:1147.74200567, Protein NB mixture loss:828.87382196, Protein background KL:101.02503644, GP KLD loss:0.14210714, Gaussian KLD loss:1.08246394, noise regularization:0.000000
# Current beta 13.584666556218153
# Current kernel scale tensor([20.0000])
# Training epoch 15, validating ELBO:2092.53653185
# Training epoch 16, ELBO:2083.11725949, Gene NB loss:1143.82404565, Protein NB mixture loss:826.25977553, Protein background KL:96.88840719, GP KLD loss:0.13981638, Gaussian KLD loss:1.04635442, noise regularization:0.000000
# Current beta 13.655988781619609
# Current kernel scale tensor([19.9841])
# Training epoch 16, validating ELBO:2065.78961088
# Training epoch 17, ELBO:2069.53786750, Gene NB loss:1142.25700387, Protein NB mixture loss:824.72622263, Protein background KL:87.72955442, GP KLD loss:0.14925322, Gaussian KLD loss:0.93433745, noise regularization:0.000000
# Current beta 13.72364454484797
# Current kernel scale tensor([19.9674])
# Training epoch 17, validating ELBO:2070.06859281
# Training epoch 18, ELBO:2057.54765602, Gene NB loss:1138.31373039, Protein NB mixture loss:821.81403115, Protein background KL:83.02425023, GP KLD loss:0.16833182, Gaussian KLD loss:0.87887574, noise regularization:0.000000
# Current beta 13.784628631195298
# Current kernel scale tensor([19.9509])
# Training epoch 18, validating ELBO:2041.62419415
# Training epoch 19, ELBO:2056.25259622, Gene NB loss:1139.70806918, Protein NB mixture loss:821.42473668, Protein background KL:81.80748252, GP KLD loss:0.15607381, Gaussian KLD loss:0.80822841, noise regularization:0.000000
# Current beta 13.838472095074907
# Current kernel scale tensor([19.9345])
# Training epoch 19, validating ELBO:2048.78444584
# Training epoch 20, ELBO:2036.86317525, Gene NB loss:1131.87874571, Protein NB mixture loss:817.09641700, Protein background KL:74.16937419, GP KLD loss:0.15643738, Gaussian KLD loss:0.83353887, noise regularization:0.000000
# Current beta 13.887995336528375
# Current kernel scale tensor([19.9181])
# Training epoch 20, validating ELBO:2041.67679791
# Training epoch 21, ELBO:2037.18627065, Gene NB loss:1132.86579132, Protein NB mixture loss:817.08058486, Protein background KL:72.94067982, GP KLD loss:0.17452966, Gaussian KLD loss:0.85374839, noise regularization:0.000000
# Current beta 13.93747236985018
# Current kernel scale tensor([19.9007])
# Training epoch 21, validating ELBO:2031.67222281
# Training epoch 22, ELBO:2041.93671560, Gene NB loss:1136.23161127, Protein NB mixture loss:819.38068350, Protein background KL:74.14378235, GP KLD loss:0.19384742, Gaussian KLD loss:0.67896892, noise regularization:0.000000
# Current beta 13.985026329975055
# Current kernel scale tensor([19.8860])
# Training epoch 22, validating ELBO:2051.24413243
# Training epoch 23, ELBO:2031.57650362, Gene NB loss:1129.63399360, Protein NB mixture loss:815.93465340, Protein background KL:73.03422904, GP KLD loss:0.18438855, Gaussian KLD loss:0.74217219, noise regularization:0.000000
# Current beta 14.028452238991123
# Current kernel scale tensor([19.8778])
# Training epoch 23, validating ELBO:2025.31675676
# Training epoch 24, ELBO:2023.80569873, Gene NB loss:1132.50265931, Protein NB mixture loss:814.70024772, Protein background KL:62.54233149, GP KLD loss:0.19354368, Gaussian KLD loss:0.80762193, noise regularization:0.000000
# Current beta 14.071533751575089
# Current kernel scale tensor([19.8672])
# Training epoch 24, validating ELBO:2008.38191262
# Training epoch 25, ELBO:2013.79225400, Gene NB loss:1127.83963704, Protein NB mixture loss:812.91777440, Protein background KL:60.16367429, GP KLD loss:0.22531914, Gaussian KLD loss:0.68827746, noise regularization:0.000000
# Current beta 14.11704548659434
# Current kernel scale tensor([19.8542])
# Training epoch 25, validating ELBO:2007.27582046
# Training epoch 26, ELBO:2007.75361779, Gene NB loss:1126.42042562, Protein NB mixture loss:811.43893363, Protein background KL:57.16649309, GP KLD loss:0.25419990, Gaussian KLD loss:0.64633548, noise regularization:0.000000
# Current beta 14.161125694907733
# Current kernel scale tensor([19.8384])
# Training epoch 26, validating ELBO:2006.93583315
# Training epoch 27, ELBO:1998.36374192, Gene NB loss:1125.31224814, Protein NB mixture loss:810.22148068, Protein background KL:50.75229828, GP KLD loss:0.24728867, Gaussian KLD loss:0.60469360, noise regularization:0.000000
# Current beta 14.200188625465232
# Current kernel scale tensor([19.8213])
# Training epoch 27, validating ELBO:1996.47650658
# Training epoch 28, ELBO:1996.66272047, Gene NB loss:1125.12594377, Protein NB mixture loss:808.82364655, Protein background KL:50.28319844, GP KLD loss:0.26775088, Gaussian KLD loss:0.60671538, noise regularization:0.000000
# Current beta 14.23735216145123
# Current kernel scale tensor([19.8106])
# Training epoch 28, validating ELBO:2003.87559810
# Training epoch 29, ELBO:1987.99138189, Gene NB loss:1121.03543311, Protein NB mixture loss:805.13433048, Protein background KL:49.13598523, GP KLD loss:0.28436396, Gaussian KLD loss:0.60578418, noise regularization:0.000000
# Current beta 14.274527569147422
# Current kernel scale tensor([19.7999])
# Training epoch 29, validating ELBO:1987.86917952
# Training epoch 30, ELBO:1980.41850055, Gene NB loss:1118.24192434, Protein NB mixture loss:804.96190014, Protein background KL:45.15232179, GP KLD loss:0.29353729, Gaussian KLD loss:0.55066101, noise regularization:0.000000
# Current beta 14.31173602319301
# Current kernel scale tensor([19.7906])
# Training epoch 30, validating ELBO:1988.77233615
# Training epoch 31, ELBO:1973.93661022, Gene NB loss:1118.98001981, Protein NB mixture loss:802.75304536, Protein background KL:39.73691040, GP KLD loss:0.30990840, Gaussian KLD loss:0.56031603, noise regularization:0.000000
# Current beta 14.348048416598232
# Current kernel scale tensor([19.7850])
# Training epoch 31, validating ELBO:1981.69922274
# Training epoch 32, ELBO:1967.20525504, Gene NB loss:1114.84232368, Protein NB mixture loss:802.02883940, Protein background KL:37.67347279, GP KLD loss:0.31746396, Gaussian KLD loss:0.56409731, noise regularization:0.000000
# Current beta 14.384724012752462
# Current kernel scale tensor([19.7783])
# Training epoch 32, validating ELBO:1979.79828389
# Training epoch 33, ELBO:1963.66452283, Gene NB loss:1115.85688892, Protein NB mixture loss:801.72616191, Protein background KL:33.45275693, GP KLD loss:0.34595157, Gaussian KLD loss:0.53111931, noise regularization:0.000000
# Current beta 14.422752981071389
# Current kernel scale tensor([19.7732])
# Training epoch 33, validating ELBO:1980.99634803
# Training epoch 34, ELBO:1964.05560400, Gene NB loss:1114.76389089, Protein NB mixture loss:798.22370928, Protein background KL:38.33606586, GP KLD loss:0.37198627, Gaussian KLD loss:0.50991042, noise regularization:0.000000
# Current beta 14.460671304849908
# Current kernel scale tensor([19.7685])
# Training epoch 34, validating ELBO:1981.28681907
# Training epoch 35, ELBO:1954.94181957, Gene NB loss:1111.25939719, Protein NB mixture loss:797.90282823, Protein background KL:33.44971632, GP KLD loss:0.36260237, Gaussian KLD loss:0.48921011, noise regularization:0.000000
# Current beta 14.497490675950154
# Current kernel scale tensor([19.7626])
# Training epoch 35, validating ELBO:1980.55322099
# Training epoch 36, ELBO:1950.70749794, Gene NB loss:1110.34247577, Protein NB mixture loss:796.81173192, Protein background KL:30.83986648, GP KLD loss:0.35013534, Gaussian KLD loss:0.52597173, noise regularization:0.000000
# Current beta 14.534383317460957
# Current kernel scale tensor([19.7614])
# Training epoch 36, validating ELBO:1973.12013815
# Training epoch 37, ELBO:1949.39333694, Gene NB loss:1110.77021891, Protein NB mixture loss:795.73601728, Protein background KL:30.86472388, GP KLD loss:0.35201937, Gaussian KLD loss:0.47438917, noise regularization:0.000000
# Current beta 14.569939768845538
# Current kernel scale tensor([19.7591])
# Training epoch 37, validating ELBO:1996.13635239
# Training epoch 38, ELBO:1953.26426745, Gene NB loss:1109.36834460, Protein NB mixture loss:796.32268147, Protein background KL:35.22254357, GP KLD loss:0.35800614, Gaussian KLD loss:0.48891576, noise regularization:0.000000
# Current beta 14.605050366203406
# Current kernel scale tensor([19.7630])
# Training epoch 38, validating ELBO:1966.71075169
# Training epoch 39, ELBO:1951.23806864, Gene NB loss:1108.66563234, Protein NB mixture loss:796.36624602, Protein background KL:33.87915323, GP KLD loss:0.37346744, Gaussian KLD loss:0.46981503, noise regularization:0.000000
# Current beta 14.638752223893771
# Current kernel scale tensor([19.7606])
# Training epoch 39, validating ELBO:1979.12058833
# Training epoch 40, ELBO:1953.56291622, Gene NB loss:1110.86283754, Protein NB mixture loss:796.31895966, Protein background KL:33.96801013, GP KLD loss:0.36287911, Gaussian KLD loss:0.48433917, noise regularization:0.000000
# Current beta 14.673277605994485
# Current kernel scale tensor([19.7653])
# Training epoch 40, validating ELBO:1951.25107920
# Training epoch 41, ELBO:1937.82451403, Gene NB loss:1107.23155114, Protein NB mixture loss:792.60598265, Protein background KL:25.80037737, GP KLD loss:0.34851456, Gaussian KLD loss:0.48128929, noise regularization:0.000000
# Current beta 14.707463991429924
# Current kernel scale tensor([19.7661])
# Training epoch 41, validating ELBO:1953.30947792
# Training epoch 42, ELBO:1932.09284534, Gene NB loss:1104.00490549, Protein NB mixture loss:790.62548854, Protein background KL:24.80548577, GP KLD loss:0.35663134, Gaussian KLD loss:0.50319965, noise regularization:0.000000
# Current beta 14.741953030325597
# Current kernel scale tensor([19.7661])
# Training epoch 42, validating ELBO:1945.25413235
# Training epoch 43, ELBO:1933.43637516, Gene NB loss:1104.39900154, Protein NB mixture loss:790.59969891, Protein background KL:25.99003939, GP KLD loss:0.35909169, Gaussian KLD loss:0.48453178, noise regularization:0.000000
# Current beta 14.776495135919319
# Current kernel scale tensor([19.7664])
# Training epoch 43, validating ELBO:1939.61397894
# Training epoch 44, ELBO:1922.41742025, Gene NB loss:1100.14148204, Protein NB mixture loss:788.92132076, Protein background KL:20.99542359, GP KLD loss:0.36656096, Gaussian KLD loss:0.46910981, noise regularization:0.000000
# Current beta 14.810890116004112
# Current kernel scale tensor([19.7667])
# Training epoch 44, validating ELBO:1938.20690326
# Training epoch 45, ELBO:1924.74280716, Gene NB loss:1101.59121384, Protein NB mixture loss:788.26760231, Protein background KL:22.19852730, GP KLD loss:0.36928430, Gaussian KLD loss:0.48647020, noise regularization:0.000000
# Current beta 14.845326132584109
# Current kernel scale tensor([19.7690])
# Training epoch 45, validating ELBO:1936.65090933
# Training epoch 46, ELBO:1919.85190134, Gene NB loss:1100.75756106, Protein NB mixture loss:786.19668862, Protein background KL:19.98938812, GP KLD loss:0.36735019, Gaussian KLD loss:0.50139263, noise regularization:0.000000
# Current beta 14.880764968724765
# Current kernel scale tensor([19.7734])
# Training epoch 46, validating ELBO:1929.85020354
# Training epoch 47, ELBO:1916.07830765, Gene NB loss:1098.33779610, Protein NB mixture loss:784.93796047, Protein background KL:19.82950358, GP KLD loss:0.37001265, Gaussian KLD loss:0.50099062, noise regularization:0.000000
# Current beta 14.917258502964286
# Current kernel scale tensor([19.7757])
# Training epoch 47, validating ELBO:1930.48706746
# Training epoch 48, ELBO:1915.23842927, Gene NB loss:1098.86165044, Protein NB mixture loss:784.89926804, Protein background KL:18.85263419, GP KLD loss:0.36567796, Gaussian KLD loss:0.47987251, noise regularization:0.000000
# Current beta 14.95363706366767
# Current kernel scale tensor([19.7796])
# Training epoch 48, validating ELBO:1932.20437562
# Training epoch 49, ELBO:1913.21994895, Gene NB loss:1097.64231534, Protein NB mixture loss:783.96561393, Protein background KL:18.87653923, GP KLD loss:0.36841621, Gaussian KLD loss:0.48249221, noise regularization:0.000000
# Current beta 14.989308389853015
# Current kernel scale tensor([19.7817])
# Training epoch 49, validating ELBO:1927.02595474
# Training epoch 50, ELBO:1907.52236367, Gene NB loss:1095.08347298, Protein NB mixture loss:781.97065078, Protein background KL:17.71552988, GP KLD loss:0.36185813, Gaussian KLD loss:0.48818799, noise regularization:0.000000
# Current beta 15.02423576640164
# Current kernel scale tensor([19.7845])
# Training epoch 50, validating ELBO:1933.17498309
# Training epoch 51, ELBO:1909.90761693, Gene NB loss:1096.84233739, Protein NB mixture loss:781.46501997, Protein background KL:18.36802077, GP KLD loss:0.36979253, Gaussian KLD loss:0.51015316, noise regularization:0.000000
# Current beta 15.059991097760077
# Current kernel scale tensor([19.7891])
# Training epoch 51, validating ELBO:1930.61309447
# Training epoch 52, ELBO:1907.06348027, Gene NB loss:1095.26372851, Protein NB mixture loss:780.67485053, Protein background KL:17.52988030, GP KLD loss:0.38455902, Gaussian KLD loss:0.51733069, noise regularization:0.000000
# Current beta 15.097451694208026
# Current kernel scale tensor([19.7924])
# Training epoch 52, validating ELBO:1927.51107351
# Training epoch 53, ELBO:1902.78681918, Gene NB loss:1092.93991611, Protein NB mixture loss:779.74016721, Protein background KL:16.91993379, GP KLD loss:0.37872665, Gaussian KLD loss:0.49388502, noise regularization:0.000000
# Current beta 15.136156177379055
# Current kernel scale tensor([19.7953])
# Training epoch 53, validating ELBO:1928.86376217
# Training epoch 54, ELBO:1903.12801440, Gene NB loss:1093.28626128, Protein NB mixture loss:779.70116850, Protein background KL:17.47846425, GP KLD loss:0.35908940, Gaussian KLD loss:0.47667917, noise regularization:0.000000
# Current beta 15.17346172617174
# Current kernel scale tensor([19.7984])
# Training epoch 54, validating ELBO:1920.61257114
# Training epoch 55, ELBO:1899.71063425, Gene NB loss:1090.66371497, Protein NB mixture loss:778.19133892, Protein background KL:17.48989231, GP KLD loss:0.35420659, Gaussian KLD loss:0.52586215, noise regularization:0.000000
# Current beta 15.209094784885627
# Current kernel scale tensor([19.8028])
# Training epoch 55, validating ELBO:1918.04236027
# Training epoch 56, ELBO:1901.17951315, Gene NB loss:1092.43512950, Protein NB mixture loss:777.93443047, Protein background KL:17.34426536, GP KLD loss:0.35471685, Gaussian KLD loss:0.52986084, noise regularization:0.000000
# Current beta 15.245629862201955
# Current kernel scale tensor([19.8064])
# Training epoch 56, validating ELBO:1922.36014159
# Training epoch 57, ELBO:1897.35193954, Gene NB loss:1092.10893125, Protein NB mixture loss:776.66169486, Protein background KL:15.42733618, GP KLD loss:0.35281933, Gaussian KLD loss:0.50917815, noise regularization:0.000000
# Current beta 15.283432218253344
# Current kernel scale tensor([19.8094])
# Training epoch 57, validating ELBO:1918.07925755
# Training epoch 58, ELBO:1895.90599818, Gene NB loss:1088.34293224, Protein NB mixture loss:776.17368226, Protein background KL:18.30431465, GP KLD loss:0.35605082, Gaussian KLD loss:0.49932650, noise regularization:0.000000
# Current beta 15.320248417692717
# Current kernel scale tensor([19.8138])
# Training epoch 58, validating ELBO:1918.55162649
# Training epoch 59, ELBO:1891.82961163, Gene NB loss:1087.74939641, Protein NB mixture loss:774.69227237, Protein background KL:16.10786924, GP KLD loss:0.35427738, Gaussian KLD loss:0.51178813, noise regularization:0.000000
# Current beta 15.356358103515639
# Current kernel scale tensor([19.8179])
# Training epoch 59, validating ELBO:1907.66942122
# Training epoch 60, ELBO:1892.39917718, Gene NB loss:1087.76449970, Protein NB mixture loss:776.35587928, Protein background KL:15.26697279, GP KLD loss:0.34363105, Gaussian KLD loss:0.50295839, noise regularization:0.000000
# Current beta 15.392336035813079
# Current kernel scale tensor([19.8205])
# Training epoch 60, validating ELBO:1911.66821417
# Training epoch 61, ELBO:1892.41055804, Gene NB loss:1087.60628728, Protein NB mixture loss:774.29846320, Protein background KL:17.05814213, GP KLD loss:0.33749313, Gaussian KLD loss:0.53540089, noise regularization:0.000000
# Current beta 15.428417213910773
# Current kernel scale tensor([19.8238])
# Training epoch 61, validating ELBO:1910.85643538
# Training epoch 62, ELBO:1886.34071819, Gene NB loss:1085.41435980, Protein NB mixture loss:772.04442642, Protein background KL:15.48509576, GP KLD loss:0.33031398, Gaussian KLD loss:0.53724868, noise regularization:0.000000
# Current beta 15.464596711756217
# Current kernel scale tensor([19.8288])
# Training epoch 62, validating ELBO:1905.02065579
# Training epoch 63, ELBO:1882.69869078, Gene NB loss:1084.41730524, Protein NB mixture loss:770.98929646, Protein background KL:14.31709354, GP KLD loss:0.33322602, Gaussian KLD loss:0.50504879, noise regularization:0.000000
# Current beta 15.500557983105644
# Current kernel scale tensor([19.8340])
# Training epoch 63, validating ELBO:1908.29805473
# Training epoch 64, ELBO:1883.96033970, Gene NB loss:1085.78142263, Protein NB mixture loss:771.95085397, Protein background KL:13.30460730, GP KLD loss:0.34338154, Gaussian KLD loss:0.48965112, noise regularization:0.000000
# Current beta 15.53501914350637
# Current kernel scale tensor([19.8397])
# Training epoch 64, validating ELBO:1901.03365014
# Training epoch 65, ELBO:1884.73605918, Gene NB loss:1085.79234188, Protein NB mixture loss:771.26509549, Protein background KL:14.28708397, GP KLD loss:0.34144435, Gaussian KLD loss:0.51986313, noise regularization:0.000000
# Current beta 15.569197691679749
# Current kernel scale tensor([19.8433])
# Training epoch 65, validating ELBO:1908.72224232
# Training epoch 66, ELBO:1881.71256974, Gene NB loss:1084.13935056, Protein NB mixture loss:769.04353419, Protein background KL:14.97736406, GP KLD loss:0.33008025, Gaussian KLD loss:0.53964306, noise regularization:0.000000
# Current beta 15.604862847598486
# Current kernel scale tensor([19.8503])
# Training epoch 66, validating ELBO:1906.47349383
# Training epoch 67, ELBO:1880.15823697, Gene NB loss:1082.85514599, Protein NB mixture loss:769.80633413, Protein background KL:14.66738094, GP KLD loss:0.32505452, Gaussian KLD loss:0.49638197, noise regularization:0.000000
# Current beta 15.640553267874603
# Current kernel scale tensor([19.8566])
# Training epoch 67, validating ELBO:1898.71843497
# Training epoch 68, ELBO:1882.85554575, Gene NB loss:1083.48615248, Protein NB mixture loss:769.56715185, Protein background KL:16.78077823, GP KLD loss:0.32702209, Gaussian KLD loss:0.50483324, noise regularization:0.000000
# Current beta 15.674401936865502
# Current kernel scale tensor([19.8633])
# Training epoch 68, validating ELBO:1897.41299925
# Training epoch 69, ELBO:1879.49854685, Gene NB loss:1083.83303133, Protein NB mixture loss:768.66063494, Protein background KL:13.42314236, GP KLD loss:0.31917707, Gaussian KLD loss:0.54662387, noise regularization:0.000000
# Current beta 15.708048683415084
# Current kernel scale tensor([19.8705])
# Training epoch 69, validating ELBO:1895.47392480
# Training epoch 70, ELBO:1878.38420839, Gene NB loss:1082.19040440, Protein NB mixture loss:766.71370857, Protein background KL:16.05946343, GP KLD loss:0.31465174, Gaussian KLD loss:0.53902100, noise regularization:0.000000
# Current beta 15.743581693809139
# Current kernel scale tensor([19.8757])
# Training epoch 70, validating ELBO:1903.14802238
# Training epoch 71, ELBO:1879.76256126, Gene NB loss:1082.66251939, Protein NB mixture loss:766.92187206, Protein background KL:17.37026999, GP KLD loss:0.30644641, Gaussian KLD loss:0.50641164, noise regularization:0.000000
# Current beta 15.778170667085059
# Current kernel scale tensor([19.8819])
# Training epoch 71, validating ELBO:1895.90044574
# Training epoch 72, ELBO:1872.02540974, Gene NB loss:1078.80733758, Protein NB mixture loss:765.90432155, Protein background KL:14.06974994, GP KLD loss:0.30996435, Gaussian KLD loss:0.52876269, noise regularization:0.000000
# Current beta 15.811586579969232
# Current kernel scale tensor([19.8901])
# Training epoch 72, validating ELBO:1890.52806374
# Training epoch 73, ELBO:1874.31167613, Gene NB loss:1080.81151663, Protein NB mixture loss:765.41880788, Protein background KL:14.89079469, GP KLD loss:0.30290867, Gaussian KLD loss:0.53067745, noise regularization:0.000000
# Current beta 15.844418441535513
# Current kernel scale tensor([19.8984])
# Training epoch 73, validating ELBO:1890.73748678
# Training epoch 74, ELBO:1870.92333904, Gene NB loss:1077.03803082, Protein NB mixture loss:764.39432023, Protein background KL:16.54457932, GP KLD loss:0.29981038, Gaussian KLD loss:0.51664911, noise regularization:0.000000
# Current beta 15.877271387655295
# Current kernel scale tensor([19.9060])
# Training epoch 74, validating ELBO:1887.75043081
# Training epoch 75, ELBO:1871.06212442, Gene NB loss:1078.98312451, Protein NB mixture loss:764.23700999, Protein background KL:14.82071907, GP KLD loss:0.30466278, Gaussian KLD loss:0.51483373, noise regularization:0.000000
# Current beta 15.909686503941328
# Current kernel scale tensor([19.9144])
# Training epoch 75, validating ELBO:1889.33982982
# Training epoch 76, ELBO:1865.84008828, Gene NB loss:1075.23687474, Protein NB mixture loss:762.56628391, Protein background KL:14.74116384, GP KLD loss:0.29261914, Gaussian KLD loss:0.54244686, noise regularization:0.000000
# Current beta 15.941753394122994
# Current kernel scale tensor([19.9250])
# Training epoch 76, validating ELBO:1885.56450253
# Training epoch 77, ELBO:1865.18345745, Gene NB loss:1075.58881759, Protein NB mixture loss:761.66820143, Protein background KL:14.51537585, GP KLD loss:0.29787840, Gaussian KLD loss:0.54273553, noise regularization:0.000000
# Current beta 15.975137596935257
# Current kernel scale tensor([19.9335])
# Training epoch 77, validating ELBO:1888.52313718
# Training epoch 78, ELBO:1867.15580398, Gene NB loss:1078.04952677, Protein NB mixture loss:763.03697875, Protein background KL:13.47580986, GP KLD loss:0.29212044, Gaussian KLD loss:0.49559117, noise regularization:0.000000
# Current beta 16.00762588625253
# Current kernel scale tensor([19.9414])
# Training epoch 78, validating ELBO:1883.02552548
# Training epoch 79, ELBO:1863.53147106, Gene NB loss:1076.80102891, Protein NB mixture loss:760.59866439, Protein background KL:12.66970580, GP KLD loss:0.29464376, Gaussian KLD loss:0.54570018, noise regularization:0.000000
# Current beta 16.03917098318628
# Current kernel scale tensor([19.9491])
# Training epoch 79, validating ELBO:1883.39195195
# Training epoch 80, ELBO:1865.48753891, Gene NB loss:1077.56118755, Protein NB mixture loss:761.12943887, Protein background KL:12.70685024, GP KLD loss:0.29590838, Gaussian KLD loss:0.58190421, noise regularization:0.000000
# Current beta 16.072635509457804
# Current kernel scale tensor([19.9566])
# Training epoch 80, validating ELBO:1883.40758778
# Training epoch 81, ELBO:1862.86238119, Gene NB loss:1076.75724475, Protein NB mixture loss:760.64482803, Protein background KL:12.53243248, GP KLD loss:0.29263877, Gaussian KLD loss:0.51105186, noise regularization:0.000000
# Current beta 16.10723942345059
# Current kernel scale tensor([19.9640])
# Training epoch 81, validating ELBO:1881.67006213
# Training epoch 82, ELBO:1858.38141776, Gene NB loss:1073.89002670, Protein NB mixture loss:758.60516649, Protein background KL:12.62135778, GP KLD loss:0.29480560, Gaussian KLD loss:0.52807947, noise regularization:0.000000
# Current beta 16.14040321859259
# Current kernel scale tensor([19.9710])
# Training epoch 82, validating ELBO:1878.85566290
# Training epoch 83, ELBO:1860.23132930, Gene NB loss:1075.03688217, Protein NB mixture loss:759.02301052, Protein background KL:11.87546501, GP KLD loss:0.29901701, Gaussian KLD loss:0.58603245, noise regularization:0.000000
# Current beta 16.1736970620592
# Current kernel scale tensor([19.9800])
# Training epoch 83, validating ELBO:1876.52889464
# Training epoch 84, ELBO:1858.61470937, Gene NB loss:1074.91708048, Protein NB mixture loss:758.02934520, Protein background KL:11.90894965, GP KLD loss:0.29680002, Gaussian KLD loss:0.55322924, noise regularization:0.000000
# Current beta 16.209462146868233
# Current kernel scale tensor([19.9883])
# Training epoch 84, validating ELBO:1878.42648035
# Training epoch 85, ELBO:1857.96785438, Gene NB loss:1073.89172723, Protein NB mixture loss:757.58259826, Protein background KL:13.10518373, GP KLD loss:0.28758685, Gaussian KLD loss:0.53768975, noise regularization:0.000000
# Current beta 16.244913326184026
# Current kernel scale tensor([19.9951])
# Training epoch 85, validating ELBO:1875.23639505
# Training epoch 86, ELBO:1850.27126285, Gene NB loss:1069.47238556, Protein NB mixture loss:755.36925166, Protein background KL:11.64301814, GP KLD loss:0.29083079, Gaussian KLD loss:0.55717380, noise regularization:0.000000
# Current beta 16.278678945422183
# Current kernel scale tensor([20.0016])
# Training epoch 86, validating ELBO:1876.44996080
# Training epoch 87, ELBO:1856.83195634, Gene NB loss:1074.72646587, Protein NB mixture loss:756.68814936, Protein background KL:11.91167177, GP KLD loss:0.28342546, Gaussian KLD loss:0.54558435, noise regularization:0.000000
# Current beta 16.312240079602876
# Current kernel scale tensor([20.0087])
# Training epoch 87, validating ELBO:1875.68779973
# Training epoch 88, ELBO:1850.38910597, Gene NB loss:1070.29040569, Protein NB mixture loss:754.67253114, Protein background KL:11.69994252, GP KLD loss:0.29231747, Gaussian KLD loss:0.54849591, noise regularization:0.000000
# Current beta 16.346129270720567
# Current kernel scale tensor([20.0164])
# Training epoch 88, validating ELBO:1871.86486661
# Training epoch 89, ELBO:1847.84143678, Gene NB loss:1069.32829592, Protein NB mixture loss:754.05481688, Protein background KL:10.52570540, GP KLD loss:0.28626316, Gaussian KLD loss:0.56542445, noise regularization:0.000000
# Current beta 16.38015263016073
# Current kernel scale tensor([20.0237])
# Training epoch 89, validating ELBO:1871.16497872
# Training epoch 90, ELBO:1850.85791223, Gene NB loss:1070.49691322, Protein NB mixture loss:754.05925626, Protein background KL:12.24698549, GP KLD loss:0.28558276, Gaussian KLD loss:0.57176924, noise regularization:0.000000
# Current beta 16.41506640434112
# Current kernel scale tensor([20.0303])
# Training epoch 90, validating ELBO:1873.99015802
# Training epoch 91, ELBO:1849.76693806, Gene NB loss:1069.41635349, Protein NB mixture loss:754.98908027, Protein background KL:11.45643806, GP KLD loss:0.28500196, Gaussian KLD loss:0.56140779, noise regularization:0.000000
# Current beta 16.450428278392298
# Current kernel scale tensor([20.0371])
# Training epoch 91, validating ELBO:1869.90054081
# Training epoch 92, ELBO:1849.02688706, Gene NB loss:1069.21757823, Protein NB mixture loss:752.71146176, Protein background KL:13.06082668, GP KLD loss:0.28746347, Gaussian KLD loss:0.56515623, noise regularization:0.000000
# Current beta 16.485874644799107
# Current kernel scale tensor([20.0433])
# Training epoch 92, validating ELBO:1884.71318271
# Training epoch 93, ELBO:1856.49812368, Gene NB loss:1070.70112711, Protein NB mixture loss:755.02629402, Protein background KL:17.01406196, GP KLD loss:0.28111772, Gaussian KLD loss:0.55267244, noise regularization:0.000000
# Current beta 16.520326097242418
# Current kernel scale tensor([20.0499])
# Training epoch 93, validating ELBO:1870.15904027
# Training epoch 94, ELBO:1851.60852341, Gene NB loss:1069.37930416, Protein NB mixture loss:752.87790413, Protein background KL:15.36938328, GP KLD loss:0.27058022, Gaussian KLD loss:0.57511057, noise regularization:0.000000
# Current beta 16.554597285197318
# Current kernel scale tensor([20.0581])
# Training epoch 94, validating ELBO:1865.39818275
# Training epoch 95, ELBO:1847.92366963, Gene NB loss:1067.62693229, Protein NB mixture loss:752.39094704, Protein background KL:13.99605149, GP KLD loss:0.26988678, Gaussian KLD loss:0.56970489, noise regularization:0.000000
# Current beta 16.588671230949153
# Current kernel scale tensor([20.0680])
# Training epoch 95, validating ELBO:1870.71636031
# Training epoch 96, ELBO:1844.69905164, Gene NB loss:1066.64431619, Protein NB mixture loss:750.08781154, Protein background KL:13.85941205, GP KLD loss:0.26668174, Gaussian KLD loss:0.58308817, noise regularization:0.000000
# Current beta 16.62283568784029
# Current kernel scale tensor([20.0798])
# Training epoch 96, validating ELBO:1863.25577963
# Training epoch 97, ELBO:1845.40152574, Gene NB loss:1066.68866686, Protein NB mixture loss:750.89114404, Protein background KL:13.84069278, GP KLD loss:0.27233042, Gaussian KLD loss:0.56809906, noise regularization:0.000000
# Current beta 16.657511416699556
# Current kernel scale tensor([20.0894])
# Training epoch 97, validating ELBO:1877.11402131
# Training epoch 98, ELBO:1845.87868621, Gene NB loss:1068.44648815, Protein NB mixture loss:751.35557675, Protein background KL:12.58630770, GP KLD loss:0.26846757, Gaussian KLD loss:0.54077468, noise regularization:0.000000
# Current beta 16.690811811989704
# Current kernel scale tensor([20.1009])
# Training epoch 98, validating ELBO:1860.60636564
# Training epoch 99, ELBO:1845.56858767, Gene NB loss:1067.97493777, Protein NB mixture loss:750.52227508, Protein background KL:13.00231325, GP KLD loss:0.26067020, Gaussian KLD loss:0.58163191, noise regularization:0.000000
# Current beta 16.72345553520285
# Current kernel scale tensor([20.1110])
# Training epoch 99, validating ELBO:1867.11494481
# Training epoch 100, ELBO:1845.79820625, Gene NB loss:1066.66586485, Protein NB mixture loss:750.05403285, Protein background KL:15.03396941, GP KLD loss:0.25917870, Gaussian KLD loss:0.57999873, noise regularization:0.000000
# Current beta 16.756443747157
# Current kernel scale tensor([20.1205])
# Training epoch 100, validating ELBO:1861.95444746
# Training epoch 101, ELBO:1839.52646392, Gene NB loss:1064.03615857, Protein NB mixture loss:747.65177828, Protein background KL:14.06924492, GP KLD loss:0.26684448, Gaussian KLD loss:0.55426029, noise regularization:0.000000
# Current beta 16.78979528564355
# Current kernel scale tensor([20.1296])
# Training epoch 101, validating ELBO:1857.63286662
# Training epoch 102, ELBO:1838.23457038, Gene NB loss:1064.33948631, Protein NB mixture loss:748.32301346, Protein background KL:12.00302756, GP KLD loss:0.25562680, Gaussian KLD loss:0.55195970, noise regularization:0.000000
# Current beta 16.822237178966727
# Current kernel scale tensor([20.1392])
# Training epoch 102, validating ELBO:1858.57871270
# Training epoch 103, ELBO:1837.74475601, Gene NB loss:1064.40134090, Protein NB mixture loss:747.01370623, Protein background KL:12.15774353, GP KLD loss:0.26378880, Gaussian KLD loss:0.57805857, noise regularization:0.000000
# Current beta 16.854428917109257
# Current kernel scale tensor([20.1494])
# Training epoch 103, validating ELBO:1857.59625640
# Training epoch 104, ELBO:1838.56235038, Gene NB loss:1066.43388250, Protein NB mixture loss:746.93360211, Protein background KL:11.28492741, GP KLD loss:0.25439779, Gaussian KLD loss:0.57031194, noise regularization:0.000000
# Current beta 16.88753865644139
# Current kernel scale tensor([20.1587])
# Training epoch 104, validating ELBO:1855.39785972
# Training epoch 105, ELBO:1840.10932218, Gene NB loss:1067.92169588, Protein NB mixture loss:746.83536541, Protein background KL:11.98760481, GP KLD loss:0.25931214, Gaussian KLD loss:0.53151303, noise regularization:0.000000
# Current beta 16.919867042753424
# Current kernel scale tensor([20.1685])
# Training epoch 105, validating ELBO:1856.00904316
# Training epoch 106, ELBO:1829.52515795, Gene NB loss:1060.59248388, Protein NB mixture loss:744.08308210, Protein background KL:10.82831286, GP KLD loss:0.25472027, Gaussian KLD loss:0.57339271, noise regularization:0.000000
# Current beta 16.95071969639412
# Current kernel scale tensor([20.1788])
# Training epoch 106, validating ELBO:1857.69674402
# Training epoch 107, ELBO:1830.88712742, Gene NB loss:1061.18787786, Protein NB mixture loss:744.29050195, Protein background KL:11.19252059, GP KLD loss:0.25849710, Gaussian KLD loss:0.57960339, noise regularization:0.000000
# Current beta 16.982386521081647
# Current kernel scale tensor([20.1895])
# Training epoch 107, validating ELBO:1853.89141756
# Training epoch 108, ELBO:1833.19942700, Gene NB loss:1063.20578625, Protein NB mixture loss:745.58297372, Protein background KL:10.66217251, GP KLD loss:0.26014253, Gaussian KLD loss:0.54884733, noise regularization:0.000000
# Current beta 17.015075801820906
# Current kernel scale tensor([20.1995])
# Training epoch 108, validating ELBO:1852.73212203
# Training epoch 109, ELBO:1832.40695964, Gene NB loss:1062.01426909, Protein NB mixture loss:743.87589169, Protein background KL:12.70723499, GP KLD loss:0.25964275, Gaussian KLD loss:0.55139068, noise regularization:0.000000
# Current beta 17.047074566112624
# Current kernel scale tensor([20.2077])
# Training epoch 109, validating ELBO:1849.86833509
# Training epoch 110, ELBO:1832.62698063, Gene NB loss:1062.62081875, Protein NB mixture loss:743.86855238, Protein background KL:12.28517419, GP KLD loss:0.26239480, Gaussian KLD loss:0.54965264, noise regularization:0.000000
# Current beta 17.078370474623817
# Current kernel scale tensor([20.2167])
# Training epoch 110, validating ELBO:1856.99140354
# Training epoch 111, ELBO:1830.49780592, Gene NB loss:1061.29329875, Protein NB mixture loss:744.17646572, Protein background KL:10.95893701, GP KLD loss:0.25319513, Gaussian KLD loss:0.57003230, noise regularization:0.000000
# Current beta 17.10965049995705
# Current kernel scale tensor([20.2253])
# Training epoch 111, validating ELBO:1847.35451068
# Training epoch 112, ELBO:1833.38851280, Gene NB loss:1062.16474285, Protein NB mixture loss:743.49444776, Protein background KL:13.19660587, GP KLD loss:0.25877770, Gaussian KLD loss:0.59000704, noise regularization:0.000000
# Current beta 17.14221805032956
# Current kernel scale tensor([20.2339])
# Training epoch 112, validating ELBO:1848.30355832
# Training epoch 113, ELBO:1829.02726218, Gene NB loss:1061.13152888, Protein NB mixture loss:742.62781530, Protein background KL:11.07585634, GP KLD loss:0.25784006, Gaussian KLD loss:0.56945565, noise regularization:0.000000
# Current beta 17.175437173524816
# Current kernel scale tensor([20.2430])
# Training epoch 113, validating ELBO:1846.82145512
# Training epoch 114, ELBO:1829.85768274, Gene NB loss:1062.10712138, Protein NB mixture loss:742.71060705, Protein background KL:10.92600703, GP KLD loss:0.25883372, Gaussian KLD loss:0.56231902, noise regularization:0.000000
# Current beta 17.208744747336723
# Current kernel scale tensor([20.2508])
# Training epoch 114, validating ELBO:1848.44282582
# Training epoch 115, ELBO:1827.76390586, Gene NB loss:1060.57235747, Protein NB mixture loss:741.82908586, Protein background KL:10.80654607, GP KLD loss:0.25569559, Gaussian KLD loss:0.58953865, noise regularization:0.000000
# Current beta 17.241885434890566
# Current kernel scale tensor([20.2593])
# Training epoch 115, validating ELBO:1847.79325249
# Training epoch 116, ELBO:1824.23810223, Gene NB loss:1058.16476536, Protein NB mixture loss:740.87047630, Protein background KL:10.94978044, GP KLD loss:0.24805494, Gaussian KLD loss:0.57800949, noise regularization:0.000000
# Current beta 17.27533638481644
# Current kernel scale tensor([20.2674])
# Training epoch 116, validating ELBO:1850.47803654
# Training epoch 117, ELBO:1829.70414594, Gene NB loss:1061.11876396, Protein NB mixture loss:742.69501983, Protein background KL:12.02538013, GP KLD loss:0.25532914, Gaussian KLD loss:0.54668642, noise regularization:0.000000
# Current beta 17.307848635581678
# Current kernel scale tensor([20.2766])
# Training epoch 117, validating ELBO:1843.54233721
# Training epoch 118, ELBO:1828.83919222, Gene NB loss:1061.13160718, Protein NB mixture loss:741.23106632, Protein background KL:11.45079772, GP KLD loss:0.24825426, Gaussian KLD loss:0.61927618, noise regularization:0.000000
# Current beta 17.340314431911295
# Current kernel scale tensor([20.2865])
# Training epoch 118, validating ELBO:1846.73938821
# Training epoch 119, ELBO:1824.65180810, Gene NB loss:1058.81967062, Protein NB mixture loss:740.54790493, Protein background KL:10.73469231, GP KLD loss:0.24362140, Gaussian KLD loss:0.59483402, noise regularization:0.000000
# Current beta 17.37425308433884
# Current kernel scale tensor([20.2963])
# Training epoch 119, validating ELBO:1843.86954680
# Training epoch 120, ELBO:1827.44169307, Gene NB loss:1060.99114142, Protein NB mixture loss:740.15626235, Protein background KL:12.14571808, GP KLD loss:0.24525202, Gaussian KLD loss:0.56848841, noise regularization:0.000000
# Current beta 17.408728633659116
# Current kernel scale tensor([20.3073])
# Training epoch 120, validating ELBO:1842.95455637
# Training epoch 121, ELBO:1822.78278259, Gene NB loss:1057.95296169, Protein NB mixture loss:739.46220070, Protein background KL:10.90335010, GP KLD loss:0.24194774, Gaussian KLD loss:0.58832507, noise regularization:0.000000
# Current beta 17.441035767812103
# Current kernel scale tensor([20.3169])
# Training epoch 121, validating ELBO:1840.84115661
# Training epoch 122, ELBO:1819.38349331, Gene NB loss:1057.45649065, Protein NB mixture loss:737.27584175, Protein background KL:9.89917107, GP KLD loss:0.24368763, Gaussian KLD loss:0.60154132, noise regularization:0.000000
# Current beta 17.473935869721224
# Current kernel scale tensor([20.3272])
# Training epoch 122, validating ELBO:1841.25640791
# Training epoch 123, ELBO:1824.65229989, Gene NB loss:1060.28950269, Protein NB mixture loss:739.88865079, Protein background KL:10.18281207, GP KLD loss:0.24003343, Gaussian KLD loss:0.57725117, noise regularization:0.000000
# Current beta 17.50725974793822
# Current kernel scale tensor([20.3368])
# Training epoch 123, validating ELBO:1839.01049379
# Training epoch 124, ELBO:1819.57794725, Gene NB loss:1058.67889611, Protein NB mixture loss:737.29034498, Protein background KL:9.36608853, GP KLD loss:0.23915022, Gaussian KLD loss:0.57380270, noise regularization:0.000000
# Current beta 17.539765980574003
# Current kernel scale tensor([20.3449])
# Training epoch 124, validating ELBO:1835.30956731
# Training epoch 125, ELBO:1823.69110620, Gene NB loss:1060.66444242, Protein NB mixture loss:738.78527177, Protein background KL:9.47837945, GP KLD loss:0.24044462, Gaussian KLD loss:0.60066525, noise regularization:0.000000
# Current beta 17.57183803000821
# Current kernel scale tensor([20.3542])
# Training epoch 125, validating ELBO:1838.73770953
# Training epoch 126, ELBO:1818.51726371, Gene NB loss:1057.21683998, Protein NB mixture loss:737.20344142, Protein background KL:9.78591194, GP KLD loss:0.23805965, Gaussian KLD loss:0.57581256, noise regularization:0.000000
# Current beta 17.6043538902297
# Current kernel scale tensor([20.3628])
# Training epoch 126, validating ELBO:1839.75179469
# Training epoch 127, ELBO:1816.31600265, Gene NB loss:1056.44818978, Protein NB mixture loss:735.91756638, Protein background KL:9.58491098, GP KLD loss:0.23893031, Gaussian KLD loss:0.57651299, noise regularization:0.000000
# Current beta 17.636539001129172
# Current kernel scale tensor([20.3709])
# Training epoch 127, validating ELBO:1833.13923437
# Training epoch 128, ELBO:1817.61243454, Gene NB loss:1056.52951209, Protein NB mixture loss:735.44651389, Protein background KL:11.00834024, GP KLD loss:0.23876908, Gaussian KLD loss:0.59008699, noise regularization:0.000000
# Current beta 17.668534149062353
# Current kernel scale tensor([20.3787])
# Training epoch 128, validating ELBO:1843.18012598
# Training epoch 129, ELBO:1819.76624380, Gene NB loss:1058.71253896, Protein NB mixture loss:736.72950259, Protein background KL:9.68991205, GP KLD loss:0.24122368, Gaussian KLD loss:0.58647714, noise regularization:0.000000
# Current beta 17.700897155933212
# Current kernel scale tensor([20.3867])
# Training epoch 129, validating ELBO:1834.62018337
# Training epoch 130, ELBO:1816.31503907, Gene NB loss:1056.38982283, Protein NB mixture loss:734.92554072, Protein background KL:9.80575614, GP KLD loss:0.24318334, Gaussian KLD loss:0.61458006, noise regularization:0.000000
# Current beta 17.734564254228435
# Current kernel scale tensor([20.3941])
# Training epoch 130, validating ELBO:1834.96376669
# Training epoch 131, ELBO:1816.78336899, Gene NB loss:1056.61101250, Protein NB mixture loss:734.70412237, Protein background KL:10.31270401, GP KLD loss:0.23953649, Gaussian KLD loss:0.61441455, noise regularization:0.000000
# Current beta 17.769189572651225
# Current kernel scale tensor([20.4028])
# Training epoch 131, validating ELBO:1831.62395644
# Training epoch 132, ELBO:1813.35830054, Gene NB loss:1054.93704657, Protein NB mixture loss:734.37594055, Protein background KL:9.50245272, GP KLD loss:0.23523513, Gaussian KLD loss:0.58259720, noise regularization:0.000000
# Current beta 17.803866205517565
# Current kernel scale tensor([20.4118])
# Training epoch 132, validating ELBO:1834.95296691
# Training epoch 133, ELBO:1814.85590395, Gene NB loss:1056.90395472, Protein NB mixture loss:734.42099957, Protein background KL:9.10240580, GP KLD loss:0.23757353, Gaussian KLD loss:0.57227399, noise regularization:0.000000
# Current beta 17.83644800084213
# Current kernel scale tensor([20.4212])
# Training epoch 133, validating ELBO:1829.23395681
# Training epoch 134, ELBO:1812.90890462, Gene NB loss:1055.49843157, Protein NB mixture loss:733.27356970, Protein background KL:9.24424123, GP KLD loss:0.23156954, Gaussian KLD loss:0.60282560, noise regularization:0.000000
# Current beta 17.868148432134912
# Current kernel scale tensor([20.4290])
# Training epoch 134, validating ELBO:1832.30150388
# Training epoch 135, ELBO:1812.30013588, Gene NB loss:1056.25428503, Protein NB mixture loss:731.87294050, Protein background KL:9.13719909, GP KLD loss:0.23420389, Gaussian KLD loss:0.60670705, noise regularization:0.000000
# Current beta 17.901360167774644
# Current kernel scale tensor([20.4368])
# Training epoch 135, validating ELBO:1832.09243748
# Training epoch 136, ELBO:1815.24830920, Gene NB loss:1056.85518098, Protein NB mixture loss:735.11040123, Protein background KL:8.84244353, GP KLD loss:0.24016896, Gaussian KLD loss:0.56592821, noise regularization:0.000000
# Current beta 17.934395414681024
# Current kernel scale tensor([20.4454])
# Training epoch 136, validating ELBO:1826.12343809
# Training epoch 137, ELBO:1809.57933778, Gene NB loss:1053.12108609, Protein NB mixture loss:731.58083034, Protein background KL:9.74559430, GP KLD loss:0.23517684, Gaussian KLD loss:0.60796833, noise regularization:0.000000
# Current beta 17.96668909179413
# Current kernel scale tensor([20.4531])
# Training epoch 137, validating ELBO:1831.64666853
# Training epoch 138, ELBO:1810.32774849, Gene NB loss:1053.61522583, Protein NB mixture loss:731.70591027, Protein background KL:9.52008473, GP KLD loss:0.23675484, Gaussian KLD loss:0.62461211, noise regularization:0.000000
# Current beta 18.00046393514895
# Current kernel scale tensor([20.4613])
# Training epoch 138, validating ELBO:1837.43749601
# Training epoch 139, ELBO:1814.16599989, Gene NB loss:1055.96420871, Protein NB mixture loss:732.86210465, Protein background KL:10.36937085, GP KLD loss:0.23854654, Gaussian KLD loss:0.59251523, noise regularization:0.000000
# Current beta 18.03539844694675
# Current kernel scale tensor([20.4695])
# Training epoch 139, validating ELBO:1829.22406872
# ...
# Training epoch 1944, ELBO:1694.98406574, Gene NB loss:1026.02705122, Protein NB mixture loss:657.03375120, Protein background KL:0.91515687, GP KLD loss:0.44093352, Gaussian KLD loss:0.00295341, noise regularization:0.000000
# Current beta 24.796259210523644
# Current kernel scale tensor([6.0788])
# Training epoch 1944, validating ELBO:1685.46965089
# Training epoch 1945, ELBO:1693.03780301, Gene NB loss:1024.80965795, Protein NB mixture loss:656.27800785, Protein background KL:0.59338984, GP KLD loss:0.45488141, Gaussian KLD loss:0.00315477, noise regularization:0.000000
# Current beta 24.791349633135756
# Current kernel scale tensor([6.0810])
# Training epoch 1945, validating ELBO:1686.07436756
# Training epoch 1946, ELBO:1692.97548874, Gene NB loss:1025.59495702, Protein NB mixture loss:655.59079856, Protein background KL:0.77925646, GP KLD loss:0.44151385, Gaussian KLD loss:0.00264768, noise regularization:0.000000
# Current beta 24.78623856537802
# Current kernel scale tensor([6.0812])
# Training epoch 1946, validating ELBO:1685.38680239
# Training epoch 1947, ELBO:1694.19922827, Gene NB loss:1027.26096840, Protein NB mixture loss:655.15584944, Protein background KL:1.05897051, GP KLD loss:0.43028991, Gaussian KLD loss:0.00237910, noise regularization:0.000000
# Current beta 24.78086410518806
# Current kernel scale tensor([6.0781])
# Training epoch 1947, validating ELBO:1684.51188129
# Training epoch 1948, ELBO:1694.81093225, Gene NB loss:1025.27702661, Protein NB mixture loss:657.13618121, Protein background KL:1.29853059, GP KLD loss:0.44576671, Gaussian KLD loss:0.00216754, noise regularization:0.000000
# Current beta 24.77498209796653
# Current kernel scale tensor([6.0742])
# Training epoch 1948, validating ELBO:1684.69892784
# Training epoch 1949, ELBO:1695.12939099, Gene NB loss:1026.02263632, Protein NB mixture loss:657.01371710, Protein background KL:0.83090282, GP KLD loss:0.45271752, Gaussian KLD loss:0.00189738, noise regularization:0.000000
# Current beta 24.769428749692686
# Current kernel scale tensor([6.0681])
# Training epoch 1949, validating ELBO:1684.98921591
# Training epoch 1950, ELBO:1694.98472626, Gene NB loss:1026.56121603, Protein NB mixture loss:656.44749054, Protein background KL:1.17920871, GP KLD loss:0.43417239, Gaussian KLD loss:0.00175546, noise regularization:0.000000
# Current beta 24.764053389490197
# Current kernel scale tensor([6.0641])
# Training epoch 1950, validating ELBO:1686.09661929
# Training epoch 1951, ELBO:1690.43707153, Gene NB loss:1022.54918463, Protein NB mixture loss:655.03239571, Protein background KL:1.90557996, GP KLD loss:0.43989359, Gaussian KLD loss:0.00231487, noise regularization:0.000000
# Current beta 24.758252682265432
# Current kernel scale tensor([6.0626])
# Training epoch 1951, validating ELBO:1686.05990236
# Training epoch 1952, ELBO:1693.99119173, Gene NB loss:1026.46474120, Protein NB mixture loss:655.69292609, Protein background KL:0.89074561, GP KLD loss:0.43987895, Gaussian KLD loss:0.00214538, noise regularization:0.000000
# Current beta 24.752345236111417
# Current kernel scale tensor([6.0626])
# Training epoch 1952, validating ELBO:1685.47407585
# Training epoch 1953, ELBO:1694.02448041, Gene NB loss:1025.67648093, Protein NB mixture loss:656.55802717, Protein background KL:0.65252645, GP KLD loss:0.44810509, Gaussian KLD loss:0.00188952, noise regularization:0.000000
# Current beta 24.746812868784772
# Current kernel scale tensor([6.0667])
# Training epoch 1953, validating ELBO:1684.13676385
# Training epoch 1954, ELBO:1690.04858793, Gene NB loss:1023.88941582, Protein NB mixture loss:654.45455368, Protein background KL:0.47636020, GP KLD loss:0.45163803, Gaussian KLD loss:0.00212304, noise regularization:0.000000
# Current beta 24.74163752829972
# Current kernel scale tensor([6.0669])
# Training epoch 1954, validating ELBO:1684.27647132
# Training epoch 1955, ELBO:1694.84729799, Gene NB loss:1026.33246873, Protein NB mixture loss:657.17816225, Protein background KL:0.33970829, GP KLD loss:0.44233590, Gaussian KLD loss:0.00216964, noise regularization:0.000000
# Current beta 24.736678051736813
# Current kernel scale tensor([6.0698])
# Training epoch 1955, validating ELBO:1683.12465700
# Training epoch 1956, ELBO:1691.34704016, Gene NB loss:1025.27767953, Protein NB mixture loss:654.76846636, Protein background KL:0.55656622, GP KLD loss:0.43238544, Gaussian KLD loss:0.00199711, noise regularization:0.000000
# Current beta 24.731180335427894
# Current kernel scale tensor([6.0690])
# Training epoch 1956, validating ELBO:1686.37446842
# Training epoch 1957, ELBO:1694.42212800, Gene NB loss:1026.00033957, Protein NB mixture loss:656.44923177, Protein background KL:1.57543782, GP KLD loss:0.41828747, Gaussian KLD loss:0.00215892, noise regularization:0.000000
# Current beta 24.724551965827377
# Current kernel scale tensor([6.0709])
# Training epoch 1957, validating ELBO:1686.13832407
# Training epoch 1958, ELBO:1693.43316350, Gene NB loss:1026.77007840, Protein NB mixture loss:655.40930070, Protein background KL:0.62626687, GP KLD loss:0.42698183, Gaussian KLD loss:0.00290147, noise regularization:0.000000
# Current beta 24.717294642064566
# Current kernel scale tensor([6.0729])
# Training epoch 1958, validating ELBO:1684.34742627
# Training epoch 1959, ELBO:1695.41326683, Gene NB loss:1025.12144402, Protein NB mixture loss:657.49373646, Protein background KL:1.53078617, GP KLD loss:0.45276313, Gaussian KLD loss:0.00313252, noise regularization:0.000000
# Current beta 24.710663912406524
# Current kernel scale tensor([6.0777])
# Training epoch 1959, validating ELBO:1684.51964559
# Training epoch 1960, ELBO:1691.96207986, Gene NB loss:1022.71524716, Protein NB mixture loss:656.96351600, Protein background KL:0.85154494, GP KLD loss:0.46003703, Gaussian KLD loss:0.00262591, noise regularization:0.000000
# Current beta 24.70562202203381
# Current kernel scale tensor([6.0778])
# Training epoch 1960, validating ELBO:1684.95067555
# Training epoch 1961, ELBO:1695.70231371, Gene NB loss:1027.11057221, Protein NB mixture loss:656.88007450, Protein background KL:0.88558558, GP KLD loss:0.43541999, Gaussian KLD loss:0.00281244, noise regularization:0.000000
# Current beta 24.701123099795023
# Current kernel scale tensor([6.0780])
# Training epoch 1961, validating ELBO:1685.54368137
# Training epoch 1962, ELBO:1690.64910847, Gene NB loss:1022.97590566, Protein NB mixture loss:656.27446816, Protein background KL:0.62181455, GP KLD loss:0.43396555, Gaussian KLD loss:0.00236277, noise regularization:0.000000
# Current beta 24.695616987338223
# Current kernel scale tensor([6.0802])
# Training epoch 1962, validating ELBO:1683.56245843
# Training epoch 1963, ELBO:1692.41632344, Gene NB loss:1024.51587865, Protein NB mixture loss:656.08604151, Protein background KL:0.62666335, GP KLD loss:0.45056412, Gaussian KLD loss:0.00250259, noise regularization:0.000000
# Current beta 24.689706947670615
# Current kernel scale tensor([6.0791])
# Training epoch 1963, validating ELBO:1685.76344233
# Training epoch 1964, ELBO:1688.88233542, Gene NB loss:1022.07870300, Protein NB mixture loss:655.17326579, Protein background KL:0.64064468, GP KLD loss:0.44227787, Gaussian KLD loss:0.00287275, noise regularization:0.000000
# Current beta 24.684274778299116
# Current kernel scale tensor([6.0808])
# Training epoch 1964, validating ELBO:1683.45493635
# Training epoch 1965, ELBO:1693.83857750, Gene NB loss:1024.83110392, Protein NB mixture loss:657.02803696, Protein background KL:0.76156674, GP KLD loss:0.45220215, Gaussian KLD loss:0.00228610, noise regularization:0.000000
# Current beta 24.67936300392867
# Current kernel scale tensor([6.0810])
# Training epoch 1965, validating ELBO:1684.26887666
# Training epoch 1966, ELBO:1690.48198022, Gene NB loss:1022.74407531, Protein NB mixture loss:656.29292288, Protein background KL:0.68719116, GP KLD loss:0.43412118, Gaussian KLD loss:0.00181531, noise regularization:0.000000
# Current beta 24.674025567149723
# Current kernel scale tensor([6.0827])
# Training epoch 1966, validating ELBO:1684.09256559
# Training epoch 1967, ELBO:1692.26484676, Gene NB loss:1025.08611645, Protein NB mixture loss:655.58903597, Protein background KL:1.04625678, GP KLD loss:0.42545721, Gaussian KLD loss:0.00189095, noise regularization:0.000000
# Current beta 24.667933866144256
# Current kernel scale tensor([6.0854])
# Training epoch 1967, validating ELBO:1684.34081648
# Training epoch 1968, ELBO:1692.56465645, Gene NB loss:1025.18059239, Protein NB mixture loss:655.95580999, Protein background KL:0.78619842, GP KLD loss:0.42934606, Gaussian KLD loss:0.00211139, noise regularization:0.000000
# Current beta 24.66095899646864
# Current kernel scale tensor([6.0869])
# Training epoch 1968, validating ELBO:1685.44966400
# Training epoch 1969, ELBO:1690.65974223, Gene NB loss:1022.51067487, Protein NB mixture loss:656.78488596, Protein background KL:0.57553901, GP KLD loss:0.43555495, Gaussian KLD loss:0.00197024, noise regularization:0.000000
# Current beta 24.65414442067739
# Current kernel scale tensor([6.0868])
# Training epoch 1969, validating ELBO:1685.15900170
# Training epoch 1970, ELBO:1689.47831699, Gene NB loss:1023.01447072, Protein NB mixture loss:654.89630704, Protein background KL:0.59935483, GP KLD loss:0.44313141, Gaussian KLD loss:0.00179388, noise regularization:0.000000
# Current beta 24.647846154470788
# Current kernel scale tensor([6.0831])
# Training epoch 1970, validating ELBO:1684.75215748
# Training epoch 1971, ELBO:1694.46165449, Gene NB loss:1025.90520521, Protein NB mixture loss:656.71452616, Protein background KL:1.15000104, GP KLD loss:0.43188779, Gaussian KLD loss:0.00193877, noise regularization:0.000000
# Current beta 24.641856010818497
# Current kernel scale tensor([6.0804])
# Training epoch 1971, validating ELBO:1685.47806756
# Training epoch 1972, ELBO:1692.68981246, Gene NB loss:1025.05696896, Protein NB mixture loss:655.58481023, Protein background KL:1.13212237, GP KLD loss:0.44145495, Gaussian KLD loss:0.00156946, noise regularization:0.000000
# Current beta 24.635781667461792
# Current kernel scale tensor([6.0785])
# Training epoch 1972, validating ELBO:1685.51136595
# Training epoch 1973, ELBO:1692.10648024, Gene NB loss:1024.53560352, Protein NB mixture loss:655.68405234, Protein background KL:0.72206491, GP KLD loss:0.45129694, Gaussian KLD loss:0.00193558, noise regularization:0.000000
# Current beta 24.630142651709622
# Current kernel scale tensor([6.0774])
# Training epoch 1973, validating ELBO:1685.09494103
# Training epoch 1974, ELBO:1694.43977964, Gene NB loss:1025.80653373, Protein NB mixture loss:655.30057142, Protein background KL:2.25574730, GP KLD loss:0.44799529, Gaussian KLD loss:0.00177015, noise regularization:0.000000
# Current beta 24.625186477139653
# Current kernel scale tensor([6.0762])
# Training epoch 1974, validating ELBO:1689.30241318
# Training epoch 1975, ELBO:1701.65325841, Gene NB loss:1026.01989633, Protein NB mixture loss:655.57064030, Protein background KL:8.91900185, GP KLD loss:0.45087724, Gaussian KLD loss:0.00169119, noise regularization:0.000000
# Current beta 24.620261880405504
# Current kernel scale tensor([6.0754])
# Training epoch 1975, validating ELBO:1689.77145125
# Training epoch 1976, ELBO:1694.90313475, Gene NB loss:1024.52225379, Protein NB mixture loss:656.00809596, Protein background KL:3.39866553, GP KLD loss:0.44410908, Gaussian KLD loss:0.00166021, noise regularization:0.000000
# Current beta 24.615208537714615
# Current kernel scale tensor([6.0710])
# Training epoch 1976, validating ELBO:1690.28463095
# Training epoch 1977, ELBO:1697.55999786, Gene NB loss:1026.63635605, Protein NB mixture loss:656.51846854, Protein background KL:3.66931244, GP KLD loss:0.43447684, Gaussian KLD loss:0.00170699, noise regularization:0.000000
# Current beta 24.60970782499138
# Current kernel scale tensor([6.0682])
# Training epoch 1977, validating ELBO:1687.20561950
# Training epoch 1978, ELBO:1696.03903023, Gene NB loss:1026.31886966, Protein NB mixture loss:656.42949683, Protein background KL:2.16620984, GP KLD loss:0.45015075, Gaussian KLD loss:0.00192655, noise regularization:0.000000
# Current beta 24.603906123032992
# Current kernel scale tensor([6.0644])
# Training epoch 1978, validating ELBO:1685.39340994
# Training epoch 1979, ELBO:1698.28954578, Gene NB loss:1028.14204755, Protein NB mixture loss:657.65071801, Protein background KL:1.18306183, GP KLD loss:0.45757450, Gaussian KLD loss:0.00229773, noise regularization:0.000000
# Current beta 24.598786136688716
# Current kernel scale tensor([6.0651])
# Training epoch 1979, validating ELBO:1684.06649097
# Training epoch 1980, ELBO:1691.23090909, Gene NB loss:1022.35211669, Protein NB mixture loss:656.64779432, Protein background KL:1.13815219, GP KLD loss:0.44839995, Gaussian KLD loss:0.00258132, noise regularization:0.000000
# Current beta 24.594460772745027
# Current kernel scale tensor([6.0667])
# Training epoch 1980, validating ELBO:1685.57523553
# Training epoch 1981, ELBO:1695.31047695, Gene NB loss:1026.14706084, Protein NB mixture loss:657.63558284, Protein background KL:0.75473603, GP KLD loss:0.43545637, Gaussian KLD loss:0.00260411, noise regularization:0.000000
# Current beta 24.589581021600807
# Current kernel scale tensor([6.0668])
# Training epoch 1981, validating ELBO:1685.75138608
# Training epoch 1982, ELBO:1691.67294236, Gene NB loss:1025.31466949, Protein NB mixture loss:654.88642662, Protein background KL:0.50149787, GP KLD loss:0.44319693, Gaussian KLD loss:0.00297843, noise regularization:0.000000
# Current beta 24.584001079355225
# Current kernel scale tensor([6.0685])
# Training epoch 1982, validating ELBO:1685.80423104
# Training epoch 1983, ELBO:1694.97434615, Gene NB loss:1026.11619637, Protein NB mixture loss:657.50745142, Protein background KL:0.47094370, GP KLD loss:0.43947903, Gaussian KLD loss:0.00311175, noise regularization:0.000000
# Current beta 24.578342014041624
# Current kernel scale tensor([6.0694])
# Training epoch 1983, validating ELBO:1685.32546604
# Training epoch 1984, ELBO:1691.46141135, Gene NB loss:1024.61610640, Protein NB mixture loss:655.55924687, Protein background KL:0.36328940, GP KLD loss:0.44169185, Gaussian KLD loss:0.00275192, noise regularization:0.000000
# Current beta 24.572790922613702
# Current kernel scale tensor([6.0738])
# Training epoch 1984, validating ELBO:1684.96461167
# Training epoch 1985, ELBO:1690.44688216, Gene NB loss:1024.28253657, Protein NB mixture loss:654.63050834, Protein background KL:0.39106132, GP KLD loss:0.45102432, Gaussian KLD loss:0.00247312, noise regularization:0.000000
# Current beta 24.567343371136584
# Current kernel scale tensor([6.0725])
# Training epoch 1985, validating ELBO:1684.46064771
# Training epoch 1986, ELBO:1694.24683658, Gene NB loss:1026.38081643, Protein NB mixture loss:656.66833559, Protein background KL:0.31982360, GP KLD loss:0.43941853, Gaussian KLD loss:0.00339353, noise regularization:0.000000
# Current beta 24.562139095222918
# Current kernel scale tensor([6.0685])
# Training epoch 1986, validating ELBO:1685.48178719
# Training epoch 1987, ELBO:1690.22153871, Gene NB loss:1022.65239339, Protein NB mixture loss:656.04572147, Protein background KL:0.44673511, GP KLD loss:0.44790739, Gaussian KLD loss:0.00309459, noise regularization:0.000000
# Current beta 24.556934260627056
# Current kernel scale tensor([6.0653])
# Training epoch 1987, validating ELBO:1685.17885848
# Training epoch 1988, ELBO:1686.55834114, Gene NB loss:1021.14864413, Protein NB mixture loss:653.52330624, Protein background KL:0.62274146, GP KLD loss:0.45583386, Gaussian KLD loss:0.00287668, noise regularization:0.000000
# Current beta 24.551974793994443
# Current kernel scale tensor([6.0601])
# Training epoch 1988, validating ELBO:1686.23315658
# Training epoch 1989, ELBO:1690.07510118, Gene NB loss:1022.67594368, Protein NB mixture loss:656.14026967, Protein background KL:0.57759364, GP KLD loss:0.43250880, Gaussian KLD loss:0.00257165, noise regularization:0.000000
# Current beta 24.546992759870857
# Current kernel scale tensor([6.0574])
# Training epoch 1989, validating ELBO:1685.27775207
# EarlyStopping: run 1989 iteration
# Training time: 40910 seconds.

# %% [markdown]
# Enhancing spatial resolutions.

# %%
# Enhancing spatial resolutions
neigh = NearestNeighbors(n_neighbors=2).fit(loc)
nearest_dist = neigh.kneighbors(loc, n_neighbors=2)[0]
small_distance = np.median(nearest_dist[:,1])/4
loc_new1 = np.empty_like(loc)
loc_new2 = np.empty_like(loc)
loc_new3 = np.empty_like(loc)
loc_new4 = np.empty_like(loc)
loc_new1[:] = loc
loc_new2[:] = loc
loc_new3[:] = loc
loc_new4[:] = loc
loc_new1[:,0] = loc_new1[:,0] - small_distance
loc_new1[:,1] = loc_new1[:,1] + small_distance
loc_new2[:,0] = loc_new2[:,0] + small_distance
loc_new2[:,1] = loc_new2[:,1] + small_distance
loc_new3[:,0] = loc_new3[:,0] - small_distance
loc_new3[:,1] = loc_new3[:,1] - small_distance
loc_new4[:,0] = loc_new4[:,0] + small_distance
loc_new4[:,1] = loc_new4[:,1] - small_distance
loc_enhance = np.concatenate((loc_new1, loc_new2, loc_new3, loc_new4, loc), axis=0)

_, enhanced_gene_denoised_counts, enhanced_protein_denoised_counts = model.batching_predict_samples(X_test=loc_enhance, 
                X_train=loc, gene_Y_train=adata1.X, protein_Y_train=adata2.X, batch_size=args.batch_size, n_samples=25)
np.savetxt(args.gene_enhanced_denoised_counts_file, enhanced_gene_denoised_counts, delimiter=",")
np.savetxt(args.protein_enhanced_denoised_counts_file, enhanced_protein_denoised_counts, delimiter=",")
np.savetxt(args.enhanced_loc_file, loc_enhance, delimiter=",")

# %% [markdown]
# K-means clustering of latent embedding.

# %%
from sklearn.cluster import KMeans

latent = np.loadtxt("final_latent.txt", delimiter=",")
y_pred = KMeans(n_clusters=7, n_init=100).fit_predict(latent[:, :])

np.savetxt("kmeans_clustering_labels.txt", y_pred, delimiter=",", fmt="%i")

# %% [markdown]
# Plot results in R and ggplot2.

# %%
rm(list=ls())
library(rhdf5)
library(ggplot2)
library(cowplot)
library(repr)

# %% [markdown]
# Plot k-means clustering result.

# %%
spamultivae.label <- as.numeric(readLines("kmeans_clustering_labels.txt")) + 1
pos <- t(h5read("humantonsil_SVG.h5", "pos"))
label.dat <- data.frame(pos, label=spamultivae.label, 
                        method="spaMultiVAE")
label.dat$label <- factor(label.dat$label, levels=1:10)

ggplot(label.dat, aes(x=X1, y=X2, color=label)) + geom_point(size=1.5) + 
  scale_y_reverse() + theme_classic() + 
  theme(axis.title=element_blank(), axis.ticks=element_blank(), axis.line=element_blank(), axis.text=element_blank(),
        legend.title=element_blank(), text = element_text(size=20)) +
  guides(colour = guide_legend(override.aes = list(size=4)))
# Out:
# plot without title

# %% [markdown]
# Plot denoised protein counts.

# %%
protein.name <- h5read("humantonsil_SVG.h5", "protein")
raw.protein <- t(h5read("humantonsil_SVG.h5", "X_protein"))
colnames(raw.protein) <- protein.name
lograwprotein <- log(raw.protein+1)

protein <- read.table("protein_denoised_counts.txt", sep=",")
colnames(protein) <- protein.name
logprotein <- log(protein+1)

protein.data <- data.frame(exp=c(logprotein[, "CD23.TCTGTATAACCGTCT"], lograwprotein[, "CD23.TCTGTATAACCGTCT"], 
                                 logprotein[, "CD3.CTCATTGTAACTCCT"], lograwprotein[, "CD3.CTCATTGTAACTCCT"], 
                                 logprotein[, "IgM.TAGCGAGCCCGTATA"], lograwprotein[, "IgM.TAGCGAGCCCGTATA"], 
                                 logprotein[, "CD171..LICAM..GATGGACGACAATTC"], lograwprotein[, "CD171..LICAM..GATGGACGACAATTC"]),
                           gene=rep(c("CD23", "CD3", "IgM", "CD171"), each=2*nrow(pos)),
                           data=rep(rep(c("spaMultiVAE denoised", "raw"), each=nrow(pos)), 4),
                           x=rep(pos[,1], 8), y=rep(pos[,2], 8))
protein.data$gene <- factor(protein.data$gene, levels=c("CD23", "CD3", "IgM", "CD171"))


p1 <- ggplot(protein.data[protein.data$gene=="CD23",], aes(x=x, y=y, color=exp)) + geom_point(size=0.5) +
  facet_grid(data~gene, switch="y") + 
  scale_colour_gradientn(colours=rainbow(3, rev=T), limits=c(0, max(protein.data[protein.data$gene=="CD23","exp"]))) +
  scale_y_reverse() + theme_classic() + 
  theme(axis.title=element_blank(), axis.ticks=element_blank(), axis.line=element_blank(), axis.text=element_blank(),
        legend.title=element_blank())

p2 <- ggplot(protein.data[protein.data$gene=="CD3",], aes(x=x, y=y, color=exp)) + geom_point(size=0.5) +
  facet_grid(data~gene, switch="y") + 
  scale_colour_gradientn(colours=rainbow(3, rev=T), limits=c(0, max(protein.data[protein.data$gene=="CD3","exp"]))) +
  scale_y_reverse() + theme_classic() + 
  theme(axis.title=element_blank(), axis.ticks=element_blank(), axis.line=element_blank(), axis.text=element_blank(),
        legend.title=element_blank())

p3 <- ggplot(protein.data[protein.data$gene=="IgM",], aes(x=x, y=y, color=exp)) + geom_point(size=0.5) +
  facet_grid(data~gene, switch="y") + 
  scale_colour_gradientn(colours=rainbow(3, rev=T), limits=c(0, max(protein.data[protein.data$gene=="IgM","exp"]))) +
  scale_y_reverse() + theme_classic() + 
  theme(axis.title=element_blank(), axis.ticks=element_blank(), axis.line=element_blank(), axis.text=element_blank(),
        legend.title=element_blank())

p4 <- ggplot(protein.data[protein.data$gene=="CD171",], aes(x=x, y=y, color=exp)) + geom_point(size=0.5) +
  facet_grid(data~gene, switch="y") + 
  scale_colour_gradientn(colours=rainbow(3, rev=T), limits=c(0, max(protein.data[protein.data$gene=="CD171","exp"]))) +
  scale_y_reverse() + theme_classic() + 
  theme(axis.title=element_blank(), axis.ticks=element_blank(), axis.line=element_blank(), axis.text=element_blank(),
        legend.title=element_blank())

options(repr.plot.width=20, repr.plot.height=10)
plot_grid(p1, p2, p3, p4, scale=0.95, nrow=1)
# Out:
# plot without title

# %% [markdown]
# Plot resolution enhanced protein counts.

# %%
enhanced.pos <- read.table("enhanced_loc.txt", sep=",")
enhanced.protein <- read.table("protein_enhanced_denoised_counts.txt", sep=",")
colnames(enhanced.protein) <- protein.name
logenhanced.protein <- log(enhanced.protein+1)
enhanced.dat <- data.frame(exp=c(logenhanced.protein[, "CD23.TCTGTATAACCGTCT"], logenhanced.protein[, "CD3.CTCATTGTAACTCCT"],
                                 logenhanced.protein[, "IgM.TAGCGAGCCCGTATA"], logenhanced.protein[, "CD171..LICAM..GATGGACGACAATTC"]),
                           gene=rep(c("CD23", "CD3", "IgM", "CD171"), each=nrow(enhanced.pos)),
                           x=rep(enhanced.pos[,1], 4), y=rep(enhanced.pos[,2], 4))

p1_2 <- ggplot(enhanced.dat[enhanced.dat$gene=="CD23",], aes(x=x, y=y, color=exp)) + geom_point(size=0.15, shape=16) +
  scale_colour_gradientn(colours=rainbow(3, rev=T), limits=c(0, max(protein.data[protein.data$gene=="CD23","exp"]))) +
  scale_y_reverse() + ggtitle("CD23") + theme_classic() + 
  theme(axis.title=element_blank(), axis.ticks=element_blank(), axis.line=element_blank(), axis.text=element_blank(),
        legend.title=element_blank(), plot.title = element_text(hjust = 0.5))
p2_2 <- ggplot(enhanced.dat[enhanced.dat$gene=="CD3",], aes(x=x, y=y, color=exp)) + geom_point(size=0.15, shape=16) +
  scale_colour_gradientn(colours=rainbow(3, rev=T), limits=c(0, max(protein.data[protein.data$gene=="CD3","exp"]))) +
  scale_y_reverse() + ggtitle("CD3") + theme_classic() + 
  theme(axis.title=element_blank(), axis.ticks=element_blank(), axis.line=element_blank(), axis.text=element_blank(),
        legend.title=element_blank(), plot.title = element_text(hjust = 0.5))
p3_2 <- ggplot(enhanced.dat[enhanced.dat$gene=="IgM",], aes(x=x, y=y, color=exp)) + geom_point(size=0.15, shape=16) +
  scale_colour_gradientn(colours=rainbow(3, rev=T), limits=c(0, max(protein.data[protein.data$gene=="IgM","exp"]))) +
  scale_y_reverse() + ggtitle("IgM") + theme_classic() + 
  theme(axis.title=element_blank(), axis.ticks=element_blank(), axis.line=element_blank(), axis.text=element_blank(),
        legend.title=element_blank(), plot.title = element_text(hjust = 0.5))
p4_2 <- ggplot(enhanced.dat[enhanced.dat$gene=="CD171",], aes(x=x, y=y, color=exp)) + geom_point(size=0.15, shape=16) +
  scale_colour_gradientn(colours=rainbow(3, rev=T), limits=c(0, max(protein.data[protein.data$gene=="CD171","exp"]))) +
  scale_y_reverse() + ggtitle("CD171") + theme_classic() + 
  theme(axis.title=element_blank(), axis.ticks=element_blank(), axis.line=element_blank(), axis.text=element_blank(),
        legend.title=element_blank(), plot.title = element_text(hjust = 0.5))

options(repr.plot.width=20, repr.plot.height=5)
plot_grid(p1_2, p2_2, p3_2, p4_2, scale=0.95, nrow=1)
# Out:
# plot without title
